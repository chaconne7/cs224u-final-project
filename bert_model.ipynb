# %%
import os
import pickle
import torch

from constants import *
from pytorch_pretrained_bert import BertTokenizer, BertModel, BertForMaskedLM

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
language_model = BertForMaskedLM.from_pretrained('bert-base-uncased')
language_model.eval()

def predict_candidate(sentence, candidates):
    tokenized_text = tokenizer.tokenize(sentence)
    candidates = [tokenizer.tokenize(candidate)[0] for candidate in candidates]
    masked_index = tokenized_text.index('[MASK]')

    candidates = [x.lower() for x in candidates]
    candidates_ids = tokenizer.convert_tokens_to_ids(candidates)

    indexed_tokens = tokenizer.convert_tokens_to_ids(tokenized_text)

    segments_ids = [0] * len(tokenized_text)

    tokens_tensor = torch.tensor([indexed_tokens])
    segments_tensors = torch.tensor([segments_ids])

    predictions = language_model(tokens_tensor, segments_tensors)
    predictions_candidates = predictions[0, masked_index, candidates_ids]
    answer_idx = torch.argmax(predictions_candidates).item()
    
    print(f'The most likely word is "{candidates[answer_idx]}".')
    
    return candidates[answer_idx]

# %%
def setup_model(model_type):
    if model_type == "BERT": 
        tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
        language_model = BertForMaskedLM.from_pretrained('bert-base-uncased')
        language_model.eval()
    elif model_type == "GPT-2": 
        return 
    elif model_type == "Baevski": 
        return 
    return tokenizer, language_model

# %%
def read_examples(): 
    correct_count = 0 
    total_count = 0 
    for data_split in DATA_SPLITS: 
        for data_type in DATA_TYPES:
            path = CLEANED_PATH + data_split + data_type 
            filenames = os.listdir(path)
            for filename in filenames: 
                filename_path = path + filename
                with open(filename_path, "rb") as pickle_file: 
                    examples = pickle.load(pickle_file)
                    for example in examples: 
                        sentence = example['sentence']
                        candidates = example['candidates']
                        answer = example['answer']
                        correct_answer = predict_candidate(sentence, candidates)
                        total_count += 1
                        if answer == correct_answer: 
                          correct_count += 1  
                        
    return correct_count, total_count

# %%
# tokenizer, language_model = setup_model("BERT")
read_examples()
# Out:
# The most likely word is "help".
# The most likely word is "visit".
# The most likely word is "as".
# The most likely word is "touched".
# The most likely word is "listening".
# The most likely word is "again".
# The most likely word is "guests".
# The most likely word is "leave".
# The most likely word is "days".
# The most likely word is "different".
# The most likely word is "following".
# The most likely word is "promising".
# The most likely word is "something".
# The most likely word is "passengers".
# The most likely word is "sit".
# The most likely word is "attention".
# The most likely word is "laughed".
# The most likely word is "silent".
# The most likely word is "morning".
# The most likely word is "surprised".
# The most likely word is "talk".
# The most likely word is "smiling".
# The most likely word is "so".
# The most likely word is "found".
# The most likely word is "waiting".
# The most likely word is "happened".
# The most likely word is "asked".
# The most likely word is "breath".
# The most likely word is "what".
# The most likely word is "got".
# The most likely word is "happiness".
# The most likely word is "served".
# The most likely word is "flew".
# The most likely word is "points".
# The most likely word is "decorated".
# The most likely word is "coffee".
# The most likely word is "laughed".
# The most likely word is "seat".
# The most likely word is "back".
# The most likely word is "silent".
# The most likely word is "and".
# The most likely word is "altitude".
# The most likely word is "on".
# The most likely word is "while".
# The most likely word is "positive".
# The most likely word is "rose".
# The most likely word is "strength".
# The most likely word is "got".
# The most likely word is "shock".
# The most likely word is "keep".
# The most likely word is "different".
# The most likely word is "smiled".
# The most likely word is "dance".
# The most likely word is "allowed".
# The most likely word is "if".
# The most likely word is "courage".
# The most likely word is "slow".
# The most likely word is "laughter".
# The most likely word is "ran".
# The most likely word is "opened".
# The most likely word is "for".
# The most likely word is "spotted".
# The most likely word is "surprise".
# The most likely word is "struggling".
# The most likely word is "over".
# The most likely word is "as".
# The most likely word is "forward".
# The most likely word is "still".
# The most likely word is "planned".
# The most likely word is "if".
# The most likely word is "turned".
# The most likely word is "attention".
# The most likely word is "reached".
# The most likely word is "announced".
# The most likely word is "wore".
# The most likely word is "touch".
# The most likely word is "connection".
# The most likely word is "delightful".
# The most likely word is "trip".
# The most likely word is "treasure".
# The most likely word is "especially".
# The most likely word is "interesting".
# The most likely word is "challenging".
# The most likely word is "shame".
# The most likely word is "taken".
# The most likely word is "what".
# The most likely word is "never".
# The most likely word is "kind".
# The most likely word is "obey".
# The most likely word is "important".
# The most likely word is "game".
# The most likely word is "mother".
# The most likely word is "when".
# The most likely word is "early".
# The most likely word is "thought".
# The most likely word is "right".
# The most likely word is "behind".
# The most likely word is "accept".
# The most likely word is "trick".
# The most likely word is "taught".
# The most likely word is "behind".
# The most likely word is "some".
# The most likely word is "failed".
# The most likely word is "sure".
# The most likely word is "finding".
# The most likely word is "like".
# The most likely word is "rules".
# The most likely word is "and".
# The most likely word is "wear".
# The most likely word is "surprisingly".
# The most likely word is "ring".
# The most likely word is "lost".
# The most likely word is "quieter".
# The most likely word is "started".
# The most likely word is "remember".
# The most likely word is "peace".
# The most likely word is "work".
# The most likely word is "simplest".
# The most likely word is "more".
# The most likely word is "struggle".
# The most likely word is "bird".
# The most likely word is "so".
# The most likely word is "usual".
# The most likely word is "die".
# The most likely word is "away".
# The most likely word is "done".
# The most likely word is "obvious".
# The most likely word is "that".
# The most likely word is "sense".
# The most likely word is "to".
# The most likely word is "support".
# The most likely word is "take".
# The most likely word is "apology".
# The most likely word is "adoptive".
# The most likely word is "heartbreak".
# The most likely word is "fight".
# The most likely word is "temporary".
# The most likely word is "hesitated".
# The most likely word is "deserves".
# The most likely word is "ache".
# The most likely word is "with".
# The most likely word is "eventually".
# The most likely word is "meet".
# The most likely word is "pleased".
# The most likely word is "addition".
# The most likely word is "partly".
# The most likely word is "common".
# The most likely word is "important".
# The most likely word is "that".
# The most likely word is "no".
# The most likely word is "likely".
# The most likely word is "as".
# The most likely word is "breath".
# The most likely word is "cold".
# The most likely word is "allowed".
# The most likely word is "shadow".
# The most likely word is "mind".
# The most likely word is "hear".
# The most likely word is "leaves".
# The most likely word is "light".
# The most likely word is "finally".
# The most likely word is "stopped".
# The most likely word is "alive".
# The most likely word is "liquid".
# The most likely word is "abandoned".
# The most likely word is "content".
# The most likely word is "good".
# The most likely word is "understand".
# The most likely word is "math".
# The most likely word is "came".
# The most likely word is "on".
# The most likely word is "star".
# The most likely word is "hard".
# The most likely word is "but".
# The most likely word is "pleased".
# The most likely word is "up".
# The most likely word is "his".
# The most likely word is "wonder".
# The most likely word is "before".
# The most likely word is "careless".
# The most likely word is "something".
# The most likely word is "encouragement".
# The most likely word is "upset".
# The most likely word is "what".
# The most likely word is "battle".
# The most likely word is "playing".
# The most likely word is "game".
# The most likely word is "live".
# The most likely word is "as".
# The most likely word is "challenge".
# The most likely word is "working".
# The most likely word is "suffered".
# The most likely word is "worked".
# The most likely word is "allowed".
# The most likely word is "felt".
# The most likely word is "husband".
# The most likely word is "food".
# The most likely word is "poor".
# The most likely word is "wealthy".
# The most likely word is "accepted".
# The most likely word is "love".
# The most likely word is "fight".
# The most likely word is "talk".
# The most likely word is "listening".
# The most likely word is "murder".
# The most likely word is "low".
# The most likely word is "reply".
# The most likely word is ".".
# The most likely word is ".".
# The most likely word is "when".
# The most likely word is ".".
# The most likely word is "watching".
# The most likely word is "tried".
# The most likely word is "see".
# The most likely word is ".".
# The most likely word is ".".
# The most likely word is "independence".
# The most likely word is "death".
# The most likely word is "faded".
# The most likely word is "approached".
# The most likely word is "excitement".
# The most likely word is "unique".
# The most likely word is "per".
# The most likely word is "refusing".
# The most likely word is "sold".
# The most likely word is "take".
# The most likely word is "whispered".
# The most likely word is "held".
# The most likely word is "noticed".
# The most likely word is "as".
# The most likely word is "regardless".
# The most likely word is "wondered".
# The most likely word is "adventure".
# The most likely word is "love".
# The most likely word is "exciting".
# The most likely word is "can".
# The most likely word is "drink".
# The most likely word is "fact".
# The most likely word is "by".
# The most likely word is "or".
# The most likely word is "if".
# The most likely word is "making".
# The most likely word is "increase".
# The most likely word is "widely".
# The most likely word is "taken".
# The most likely word is "high".
# The most likely word is "forms".
# The most likely word is "making".
# The most likely word is "as".
# The most likely word is "but".
# The most likely word is "suffer".
# The most likely word is "horrible".
# The most likely word is "learn".
# The most likely word is "that".
# The most likely word is "decision".
# The most likely word is "when".
# The most likely word is "affect".
# The most likely word is "experiences".
# The most likely word is "energy".
# The most likely word is "important".
# The most likely word is "way".
# The most likely word is "aware".
# The most likely word is "even".
# The most likely word is "if".
# The most likely word is "make".
# The most likely word is "changes".
# The most likely word is "fast".
# The most likely word is "either".
# The most likely word is "cross".
# The most likely word is "where".
# The most likely word is "before".
# The most likely word is "goes".
# The most likely word is "daring".
# The most likely word is "with".
# The most likely word is "out".
# The most likely word is "burn".
# The most likely word is "from".
# The most likely word is "standard".
# The most likely word is "transmit".
# The most likely word is "takes".
# The most likely word is "unharmed".
# The most likely word is "instantly".
# The most likely word is "raise".
# The most likely word is "power".
# The most likely word is "measure".
# The most likely word is "achieve".
# The most likely word is "anger".
# The most likely word is "wife".
# The most likely word is "change".
# The most likely word is "life".
# The most likely word is "picture".
# The most likely word is "warm".
# The most likely word is "observe".
# The most likely word is "mean".
# The most likely word is "wish".
# The most likely word is "laughed".
# The most likely word is "son".
# The most likely word is "happily".
# The most likely word is "and".
# The most likely word is "obvious".
# The most likely word is "actually".
# The most likely word is "believe".
# The most likely word is "easy".
# The most likely word is "fond".
# The most likely word is "as".
# The most likely word is "killed".
# The most likely word is "offering".
# The most likely word is "insisted".
# The most likely word is "sword".
# The most likely word is "story".
# The most likely word is "describing".
# The most likely word is "known".
# The most likely word is "un".
# The most likely word is "nor".
# The most likely word is "force".
# The most likely word is "count".
# The most likely word is "clear".
# The most likely word is "dream".
# The most likely word is "stupid".
# The most likely word is "met".
# The most likely word is "shocked".
# The most likely word is "warmed".
# The most likely word is "gently".
# The most likely word is "better".
# The most likely word is "happened".
# The most likely word is "memory".
# The most likely word is "difficulties".
# The most likely word is "love".
# The most likely word is "broken".
# The most likely word is "friends".
# The most likely word is "lose".
# The most likely word is "adds".
# The most likely word is "employ".
# The most likely word is "busy".
# The most likely word is "heard".
# The most likely word is "really".
# The most likely word is "habit".
# The most likely word is "stories".
# The most likely word is "enjoying".
# The most likely word is "un".
# The most likely word is "sky".
# The most likely word is "lost".
# The most likely word is "patience".
# The most likely word is "danger".
# The most likely word is "helped".
# The most likely word is "appeared".
# The most likely word is "saved".
# The most likely word is "turn".
# The most likely word is "time".
# The most likely word is "unable".
# The most likely word is "knowledge".
# The most likely word is "serves".
# The most likely word is "additional".
# The most likely word is "experience".
# The most likely word is "encourages".
# The most likely word is "gain".
# The most likely word is "collected".
# The most likely word is "however".
# The most likely word is "means".
# The most likely word is "life".
# The most likely word is "free".
# The most likely word is "complete".
# The most likely word is "examples".
# The most likely word is "with".
# The most likely word is "benefits".
# The most likely word is "about".
# The most likely word is "finally".
# The most likely word is "so".
# The most likely word is "argue".
# The most likely word is "contribute".
# The most likely word is "however".
# The most likely word is "design".
# The most likely word is "please".
# The most likely word is "surprise".
# The most likely word is "similar".
# The most likely word is "with".
# The most likely word is "eventually".
# The most likely word is "instead".
# The most likely word is "laughed".
# The most likely word is "delight".
# The most likely word is "encouragement".
# The most likely word is "turn".
# The most likely word is "respect".
# The most likely word is "comfortable".
# The most likely word is "life".
# The most likely word is "size".
# The most likely word is "pushed".
# The most likely word is "air".
# The most likely word is "smile".
# The most likely word is "class".
# The most likely word is "course".
# The most likely word is "strong".
# The most likely word is "before".
# The most likely word is "look".
# The most likely word is "ask".
# The most likely word is "pushed".
# The most likely word is "extreme".
# The most likely word is "time".
# The most likely word is "caught".
# The most likely word is "believed".
# The most likely word is "hand".
# The most likely word is "share".
# The most likely word is "fault".
# The most likely word is "good".
# The most likely word is "great".
# The most likely word is "friends".
# The most likely word is "formal".
# The most likely word is "hot".
# The most likely word is "books".
# The most likely word is "study".
# The most likely word is "something".
# The most likely word is "writing".
# The most likely word is "public".
# The most likely word is "special".
# The most likely word is "stopped".
# The most likely word is "find".
# The most likely word is "receiving".
# The most likely word is "however".
# The most likely word is "groceries".
# The most likely word is "moved".
# The most likely word is "anger".
# The most likely word is "children".
# The most likely word is "hopeful".
# The most likely word is "before".
# The most likely word is "majority".
# The most likely word is "found".
# The most likely word is "powerful".
# The most likely word is "meant".
# The most likely word is "proud".
# The most likely word is "continue".
# The most likely word is "extra".
# The most likely word is "servant".
# The most likely word is "question".
# The most likely word is "group".
# The most likely word is "had".
# The most likely word is "promised".
# The most likely word is "left".
# The most likely word is "wondered".
# The most likely word is "confused".
# The most likely word is "important".
# The most likely word is "treat".
# The most likely word is "surprised".
# The most likely word is "straight".
# The most likely word is "faithful".
# The most likely word is "demanding".
# The most likely word is "perfectly".
# The most likely word is "tourist".
# The most likely word is "ignore".
# The most likely word is "warning".
# The most likely word is "wrote".
# The most likely word is "anxiety".
# The most likely word is "something".
# The most likely word is "books".
# The most likely word is "unexpectedly".
# The most likely word is "overcome".
# The most likely word is "sending".
# The most likely word is "choose".
# The most likely word is "happy".
# The most likely word is "understand".
# The most likely word is "continued".
# The most likely word is "stories".
# The most likely word is "serve".
# The most likely word is "means".
# The most likely word is "see".
# The most likely word is "way".
# The most likely word is "dark".
# The most likely word is "knew".
# The most likely word is "leave".
# The most likely word is "sister".
# The most likely word is "because".
# The most likely word is "who".
# The most likely word is "true".
# The most likely word is "what".
# The most likely word is "see".
# The most likely word is "for".
# The most likely word is "first".
# The most likely word is "beside".
# The most likely word is "far".
# The most likely word is "window".
# The most likely word is "living".
# The most likely word is "doctor".
# The most likely word is "needed".
# The most likely word is "someone".
# The most likely word is "good".
# The most likely word is "planned".
# The most likely word is "wait".
# The most likely word is "thanked".
# The most likely word is "office".
# The most likely word is "politely".
# The most likely word is "after".
# The most likely word is "always".
# The most likely word is "way".
# The most likely word is "however".
# The most likely word is "forced".
# The most likely word is "mentioned".
# The most likely word is "for".
# The most likely word is "saying".
# The most likely word is "challenge".
# The most likely word is "trial".
# The most likely word is "while".
# The most likely word is "concerned".
# The most likely word is "feel".
# The most likely word is "society".
# The most likely word is "quickly".
# The most likely word is "passed".
# The most likely word is "called".
# The most likely word is "laughed".
# The most likely word is "matter".
# The most likely word is "stand".
# The most likely word is "spend".
# The most likely word is "could".
# The most likely word is "park".
# The most likely word is "while".
# The most likely word is "view".
# The most likely word is "watched".
# The most likely word is "sadly".
# The most likely word is "wall".
# The most likely word is "dead".
# The most likely word is "trying".
# The most likely word is "surprise".
# The most likely word is "blind".
# The most likely word is "cancelled".
# The most likely word is "before".
# The most likely word is "matter".
# The most likely word is "little".
# The most likely word is "nowhere".
# The most likely word is "appears".
# The most likely word is "memories".
# The most likely word is "form".
# The most likely word is "happy".
# The most likely word is "change".
# The most likely word is "good".
# The most likely word is "money".
# The most likely word is "understand".
# The most likely word is "expect".
# The most likely word is "power".
# The most likely word is "go".
# The most likely word is "beaten".
# The most likely word is "talking".
# The most likely word is "found".
# The most likely word is "disappointed".
# The most likely word is "man".
# The most likely word is "running".
# The most likely word is "began".
# The most likely word is "present".
# The most likely word is "helped".
# The most likely word is "hospital".
# The most likely word is "information".
# The most likely word is "comes".
# The most likely word is "respectful".
# The most likely word is "gain".
# The most likely word is "admiration".
# The most likely word is "if".
# The most likely word is "to".
# The most likely word is "unbroken".
# The most likely word is "while".
# The most likely word is "took".
# The most likely word is "so".
# The most likely word is "saying".
# The most likely word is "reduced".
# The most likely word is "badly".
# The most likely word is "like".
# The most likely word is "broke".
# The most likely word is "won".
# The most likely word is "crowded".
# The most likely word is "close".
# The most likely word is "excited".
# The most likely word is "friendly".
# The most likely word is "mind".
# The most likely word is "possible".
# The most likely word is "bought".
# The most likely word is "heart".
# The most likely word is "baby".
# The most likely word is "wrote".
# The most likely word is "accident".
# The most likely word is "running".
# The most likely word is "tell".
# The most likely word is "officers".
# The most likely word is "but".
# The most likely word is "leader".
# The most likely word is "wrong".
# The most likely word is "could".
# The most likely word is "only".
# The most likely word is "lifted".
# The most likely word is "normally".
# The most likely word is "lover".
# The most likely word is "occasionally".
# The most likely word is "encouragement".
# The most likely word is "passengers".
# The most likely word is "thanked".
# The most likely word is "threatened".
# The most likely word is "impatiently".
# The most likely word is "laughter".
# The most likely word is "rescued".
# The most likely word is "worry".
# The most likely word is "way".
# The most likely word is "and".
# The most likely word is "solutions".
# The most likely word is "listening".
# The most likely word is "hard".
# The most likely word is "end".
# The most likely word is "most".
# The most likely word is "completely".
# The most likely word is "felt".
# The most likely word is "music".
# The most likely word is "helpless".
# The most likely word is "still".
# The most likely word is "allowed".
# The most likely word is "hands".
# The most likely word is "popular".
# The most likely word is "stand".
# The most likely word is "shared".
# The most likely word is "generally".
# The most likely word is "students".
# The most likely word is "amazing".
# The most likely word is "hold".
# The most likely word is "focusing".
# The most likely word is "spent".
# The most likely word is "talking".
# The most likely word is "place".
# The most likely word is "with".
# The most likely word is "call".
# The most likely word is "said".
# The most likely word is "only".
# The most likely word is "as".
# The most likely word is "expectation".
# The most likely word is "received".
# The most likely word is "thank".
# The most likely word is "what".
# The most likely word is "remembered".
# The most likely word is "replied".
# The most likely word is "friends".
# The most likely word is "customers".
# The most likely word is "weight".
# The most likely word is "funny".
# The most likely word is "looked".
# The most likely word is "english".
# The most likely word is "insisted".
# The most likely word is "but".
# The most likely word is "short".
# The most likely word is "covered".
# The most likely word is "hands".
# The most likely word is "seen".
# The most likely word is "about".
# The most likely word is "as".
# The most likely word is "burden".
# The most likely word is "asked".
# The most likely word is "heard".
# The most likely word is "waiting".
# The most likely word is "silence".
# The most likely word is "safety".
# The most likely word is "destruction".
# The most likely word is "fortunate".
# The most likely word is "family".
# The most likely word is "build".
# The most likely word is "cooking".
# The most likely word is "conversation".
# The most likely word is "suggestion".
# The most likely word is "look".
# The most likely word is "wondering".
# The most likely word is "follow".
# The most likely word is "above".
# The most likely word is "excellent".
# The most likely word is "respect".
# The most likely word is "left".
# The most likely word is "transport".
# The most likely word is "door".
# The most likely word is "immediately".
# The most likely word is "vain".
# The most likely word is "dark".
# The most likely word is "knew".
# The most likely word is "up".
# The most likely word is "saw".
# The most likely word is "support".
# The most likely word is "gently".
# The most likely word is "discovering".
# The most likely word is "won".
# The most likely word is "hardest".
# The most likely word is "interest".
# The most likely word is "important".
# The most likely word is "determined".
# The most likely word is "role".
# The most likely word is "grew".
# The most likely word is "confident".
# The most likely word is "fan".
# The most likely word is "children".
# The most likely word is "open".
# The most likely word is "gone".
# The most likely word is "from".
# The most likely word is "danger".
# The most likely word is "imagination".
# The most likely word is "hear".
# The most likely word is "ugly".
# The most likely word is "admit".
# The most likely word is "explained".
# The most likely word is "amazing".
# The most likely word is "neighbors".
# The most likely word is "expensive".
# The most likely word is "help".
# The most likely word is "flooding".
# The most likely word is "replaced".
# The most likely word is "instead".
# The most likely word is "even".
# The most likely word is "experience".
# The most likely word is "types".
# The most likely word is "successful".
# The most likely word is "if".
# The most likely word is "directed".
# The most likely word is "know".
# The most likely word is "provide".
# The most likely word is "goal".
# The most likely word is "and".
# The most likely word is "race".
# The most likely word is "however".
# The most likely word is "dying".
# The most likely word is "process".
# The most likely word is "announced".
# The most likely word is "gentle".
# The most likely word is "house".
# The most likely word is "follow".
# The most likely word is "careful".
# The most likely word is "obviously".
# The most likely word is "gone".
# The most likely word is "tears".
# The most likely word is "coincidence".
# The most likely word is "who".
# The most likely word is "happy".
# The most likely word is "courage".
# The most likely word is "disappointment".
# The most likely word is "set".
# The most likely word is "early".
# The most likely word is "asked".
# The most likely word is "good".
# The most likely word is "meal".
# The most likely word is "wrote".
# The most likely word is "kitchen".
# The most likely word is "table".
# The most likely word is "own".
# The most likely word is "way".
# The most likely word is "wife".
# The most likely word is "happiness".
# The most likely word is "in".
# The most likely word is "all".
# The most likely word is "simple".
# The most likely word is "walking".
# The most likely word is "refused".
# The most likely word is "around".
# The most likely word is "stuck".
# The most likely word is "first".
# The most likely word is "sounds".
# The most likely word is "good".
# The most likely word is "but".
# The most likely word is "advice".
# The most likely word is "creates".
# The most likely word is "smile".
# The most likely word is "adventure".
# The most likely word is "walk".
# The most likely word is "un".
# The most likely word is "flowed".
# The most likely word is "engaged".
# The most likely word is "existence".
# The most likely word is "casually".
# The most likely word is "back".
# The most likely word is "strange".
# The most likely word is "that".
# The most likely word is "road".
# The most likely word is "left".
# The most likely word is "face".
# The most likely word is "direction".
# The most likely word is "participated".
# The most likely word is "recall".
# The most likely word is "necessary".
# The most likely word is "same".
# The most likely word is "subject".
# The most likely word is "fear".
# The most likely word is "never".
# The most likely word is "self".
# The most likely word is "respected".
# The most likely word is "left".
# The most likely word is "tears".
# The most likely word is "pulled".
# The most likely word is "lifting".
# The most likely word is "promise".
# The most likely word is "marks".
# The most likely word is "used".
# The most likely word is "will".
# The most likely word is "even".
# The most likely word is "own".
# The most likely word is "reminded".
# The most likely word is "only".
# The most likely word is "where".
# The most likely word is "figure".
# The most likely word is "way".
# The most likely word is "rich".
# The most likely word is "encourage".
# The most likely word is "easy".
# The most likely word is "limited".
# The most likely word is "pointed".
# The most likely word is "long".
# The most likely word is "got".
# The most likely word is "immediately".
# The most likely word is "more".
# The most likely word is "high".
# The most likely word is "enjoyable".
# The most likely word is "hard".
# The most likely word is "calm".
# The most likely word is "read".
# The most likely word is "struggling".
# The most likely word is "sight".
# The most likely word is "develop".
# The most likely word is "doubt".
# The most likely word is "turn".
# The most likely word is "matter".
# The most likely word is "answering".
# The most likely word is "as".
# The most likely word is "reached".
# The most likely word is "lit".
# The most likely word is "appeared".
# The most likely word is "operate".
# The most likely word is "promise".
# The most likely word is "anything".
# The most likely word is "ancestors".
# The most likely word is "weigh".
# The most likely word is "fit".
# The most likely word is "stay".
# The most likely word is "push".
# The most likely word is "for".
# The most likely word is "becomes".
# The most likely word is "and".
# The most likely word is "why".
# The most likely word is "ability".
# The most likely word is "walk".
# The most likely word is "adapted".
# The most likely word is "sticks".
# The most likely word is "ordinary".
# The most likely word is "would".
# The most likely word is "by".
# The most likely word is "show".
# The most likely word is "until".
# The most likely word is "made".
# The most likely word is "growing".
# The most likely word is "result".
# The most likely word is "forced".
# The most likely word is "good".
# The most likely word is "long".
# The most likely word is "why".
# The most likely word is "left".
# The most likely word is "forward".
# The most likely word is "as".
# The most likely word is "carefully".
# The most likely word is "family".
# The most likely word is "prefer".
# The most likely word is "self".
# The most likely word is "dreams".
# The most likely word is "crazy".
# The most likely word is "do".
# The most likely word is "involved".
# The most likely word is "holes".
# The most likely word is "how".
# The most likely word is "try".
# The most likely word is "seated".
# The most likely word is "smiled".
# The most likely word is "more".
# The most likely word is "successes".
# The most likely word is "shouted".
# The most likely word is "stands".
# The most likely word is "help".
# The most likely word is "on".
# The most likely word is "once".
# The most likely word is "house".
# The most likely word is "summer".
# The most likely word is "average".
# The most likely word is "casual".
# The most likely word is "until".
# The most likely word is "marks".
# The most likely word is "take".
# The most likely word is "reflection".
# The most likely word is "offering".
# The most likely word is "themselves".
# The most likely word is "expensive".
# The most likely word is "more".
# The most likely word is "satisfaction".
# The most likely word is "respect".
# The most likely word is "any".
# The most likely word is "time".
# The most likely word is "separated".
# The most likely word is "finally".
# The most likely word is "food".
# The most likely word is "could".
# The most likely word is "look".
# The most likely word is "left".
# The most likely word is "right".
# The most likely word is "happened".
# The most likely word is "put".
# The most likely word is "well".
# The most likely word is "rising".
# The most likely word is "learned".
# The most likely word is "include".
# The most likely word is "unusual".
# The most likely word is "on".
# The most likely word is "but".
# The most likely word is "effectively".
# The most likely word is "started".
# The most likely word is "reporting".
# The most likely word is "suggestion".
# The most likely word is "explaining".
# The most likely word is "family".
# The most likely word is "completed".
# The most likely word is "however".
# The most likely word is "something".
# The most likely word is "difference".
# The most likely word is "happy".
# The most likely word is "words".
# The most likely word is "buy".
# The most likely word is "important".
# The most likely word is "foreign".
# The most likely word is "last".
# The most likely word is "sell".
# The most likely word is "again".
# The most likely word is "takes".
# The most likely word is "that".
# The most likely word is "products".
# The most likely word is "unable".
# The most likely word is "admitted".
# The most likely word is "decided".
# The most likely word is "lesson".
# The most likely word is "happy".
# The most likely word is "kids".
# The most likely word is "confused".
# The most likely word is "help".
# The most likely word is "bringing".
# The most likely word is "turned".
# The most likely word is "mind".
# The most likely word is "hands".
# The most likely word is "home".
# The most likely word is "left".
# The most likely word is "recovered".
# The most likely word is "picture".
# The most likely word is "read".
# The most likely word is "well".
# The most likely word is "endless".
# The most likely word is "make".
# The most likely word is "realize".
# The most likely word is "first".
# The most likely word is "hit".
# The most likely word is "accident".
# The most likely word is "excitedly".
# The most likely word is "days".
# The most likely word is "measuring".
# The most likely word is "should".
# The most likely word is "hands".
# The most likely word is "seen".
# The most likely word is "soon".
# The most likely word is "go".
# The most likely word is "mark".
# The most likely word is "long".
# The most likely word is "size".
# The most likely word is "correctly".
# The most likely word is "required".
# The most likely word is "advice".
# The most likely word is "on".
# The most likely word is "stopping".
# The most likely word is "almost".
# The most likely word is "no".
# The most likely word is "probably".
# The most likely word is "asks".
# The most likely word is "give".
# The most likely word is "admitted".
# The most likely word is "transferred".
# The most likely word is "stage".
# The most likely word is "performer".
# The most likely word is "shocking".
# The most likely word is "mind".
# The most likely word is "sleeping".
# The most likely word is "subject".
# The most likely word is "explained".
# The most likely word is "on".
# The most likely word is "tears".
# The most likely word is "touch".
# The most likely word is "should".
# The most likely word is "gift".
# The most likely word is "deeply".
# The most likely word is "upset".
# The most likely word is "do".
# The most likely word is "love".
# The most likely word is "burden".
# The most likely word is "everything".
# The most likely word is "remember".
# The most likely word is "in".
# The most likely word is "sense".
# The most likely word is "including".
# The most likely word is "name".
# The most likely word is "when".
# The most likely word is "learning".
# The most likely word is "promise".
# The most likely word is "ring".
# The most likely word is "sadness".
# The most likely word is "again".
# The most likely word is "smiling".
# The most likely word is "courage".
# The most likely word is "curiosity".
# The most likely word is "up".
# The most likely word is "no".
# The most likely word is "attracted".
# The most likely word is "until".
# The most likely word is "slightly".
# The most likely word is "put".
# The most likely word is "bent".
# The most likely word is "saw".
# The most likely word is "then".
# The most likely word is "separated".
# The most likely word is "just".
# The most likely word is "face".
# The most likely word is "name".
# The most likely word is "left".
# The most likely word is "words".
# The most likely word is "excited".
# The most likely word is "conversation".
# The most likely word is "answered".
# The most likely word is "happy".
# The most likely word is "those".
# The most likely word is "heard".
# The most likely word is "felt".
# The most likely word is "see".
# The most likely word is "sometimes".
# The most likely word is "leave".
# The most likely word is "violin".
# The most likely word is "spot".
# The most likely word is "stopped".
# The most likely word is "excited".
# The most likely word is "show".
# The most likely word is "wall".
# The most likely word is "slowly".
# The most likely word is "surprise".
# The most likely word is "money".
# The most likely word is "hand".
# The most likely word is "people".
# The most likely word is "help".
# The most likely word is "regular".
# The most likely word is "ladies".
# The most likely word is "sometimes".
# The most likely word is "playing".
# The most likely word is "fun".
# The most likely word is "at".
# The most likely word is "special".
# The most likely word is "kitchen".
# The most likely word is "politely".
# The most likely word is "embarrassed".
# The most likely word is "father".
# The most likely word is "immediately".
# The most likely word is "since".
# The most likely word is "disappointed".
# The most likely word is "stressed".
# The most likely word is "generosity".
# The most likely word is "selfish".
# The most likely word is "thanks".
# The most likely word is "deserves".
# The most likely word is "appreciated".
# The most likely word is "all".
# The most likely word is "so".
# The most likely word is "know".
# The most likely word is "seldom".
# The most likely word is "practical".
# The most likely word is "call".
# The most likely word is "known".
# The most likely word is "it".
# The most likely word is "instead".
# The most likely word is "handwriting".
# The most likely word is "likely".
# The most likely word is "prohibit".
# The most likely word is "calmly".
# The most likely word is "as".
# The most likely word is "family".
# The most likely word is "exactly".
# The most likely word is "blank".
# The most likely word is "shaking".
# The most likely word is "reply".
# The most likely word is "just".
# The most likely word is "respect".
# The most likely word is "relaxed".
# The most likely word is "find".
# The most likely word is "instead".
# The most likely word is "organized".
# The most likely word is "always".
# The most likely word is "easier".
# The most likely word is "throw".
# The most likely word is "screaming".
# The most likely word is "when".
# The most likely word is "on".
# The most likely word is "filled".
# The most likely word is "heard".
# The most likely word is "tell".
# The most likely word is "bed".
# The most likely word is "help".
# The most likely word is "floor".
# The most likely word is "so".
# The most likely word is "eyes".
# The most likely word is "year".
# The most likely word is "whenever".
# The most likely word is "hesitate".
# The most likely word is "so".
# The most likely word is "excited".
# The most likely word is "treated".
# The most likely word is "worried".
# The most likely word is "learned".
# The most likely word is "broke".
# The most likely word is "opposite".
# The most likely word is "change".
# The most likely word is "responded".
# The most likely word is "put".
# The most likely word is "happier".
# The most likely word is "lost".
# The most likely word is "happy".
# The most likely word is "previous".
# The most likely word is "anyway".
# The most likely word is "pleasure".
# The most likely word is "within".
# The most likely word is "quarter".
# The most likely word is "as".
# The most likely word is "working".
# The most likely word is "what".
# The most likely word is "missed".
# The most likely word is "problem".
# The most likely word is "criticized".
# The most likely word is "same".
# The most likely word is "adventure".
# The most likely word is "special".
# The most likely word is "sign".
# The most likely word is "worse".
# The most likely word is "loud".
# The most likely word is "with".
# The most likely word is "inspire".
# The most likely word is "will".
# The most likely word is "even".
# The most likely word is "tired".
# The most likely word is "but".
# The most likely word is "want".
# The most likely word is "nice".
# The most likely word is "say".
# The most likely word is "until".
# The most likely word is "hurry".
# The most likely word is "small".
# The most likely word is "saw".
# The most likely word is "get".

# %%
with open("data/cleaned/train/high/high1495.pickle", "rb") as pickle_file: 
    examples = pickle.load(pickle_file)
    print(examples)
